# %% [markdown]
# # Exploratory Data Analysis
# Analysis of UMKM sales data.

# %%
from google.cloud import bigquery
import pandas as pd

client = bigquery.Client()
sql = "SELECT * FROM `umkm_analytics.daily_summary` LIMIT 100"
df = client.query(sql).to_dataframe()
df.head()
